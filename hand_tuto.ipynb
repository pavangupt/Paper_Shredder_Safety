# %%
import tensorflow as tf

# %% [markdown]
# #follow these steps,
# https://c17hawke.github.io/tfod-setup/

# %%
print( tf.__version__)
# Out:
# 2.8.0

# %%
#here the version is 2.8, for hand_detection we need to change it to 1.4
#here tensorflow version is 2.8, but to implement an ssd we need tenosrflow version 1
# !python -m pip install --upgrade pip==20.2
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 5.3 MB/s
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.1.3
#     Uninstalling pip-21.1.3:
#       Successfully uninstalled pip-21.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pip-tools 6.2.0 requires pip>=20.3, but you have pip 20.2 which is incompatible.
# ...

# %%
# !pip install tensorflow-gpu==1.15
# Out:
# ...
#      |████████████████████████████████| 411.5 MB 8.1 kB/s
# ...
#      |████████████████████████████████| 503 kB 41.1 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 33.4 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.1 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=f0645436c2beb0c37eb0d8314dd6c0f3ccaa86d458498ee0ebdb0c9f872a765a
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
# ...

# %%
# !pip install tensorflow==1.15
# Out:
# ...
#      |████████████████████████████████| 412.3 MB 27 kB/s
# ...
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# tf-models-official 2.8.0 requires tensorflow~=2.8.0, but you'll have tensorflow 1.15.0 which is incompatible.
# tensorflow-text 2.8.1 requires tensorflow<2.9,>=2.8.0, but you'll have tensorflow 1.15.0 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you'll have tensorflow 1.15.0 which is incompatible.
# ...

# %%
# !pip show tensorflow
# !pip show tensorflow-gpu
# Out:
# Name: tensorflow
# Version: 1.15.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: protobuf, astor, keras-applications, wheel, gast, numpy, google-pasta, wrapt, grpcio, tensorboard, opt-einsum, tensorflow-estimator, absl-py, keras-preprocessing, six, termcolor
# Required-by: tf-models-official, tensorflow-text, kapre
# Name: tensorflow-gpu
# Version: 1.15.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# ...

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
# !nvidia-smi
# Out:
# Thu Apr  7 15:06:53 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#uninstall the curren cuda version
# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '(print $2)' | xargs -n1 dpkg --purge
# !apt-get remove cuda-
# !apt autoremove
# !apt-get update
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'nvidia-kernel-common-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-325-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-binary' for glob 'nvidia*'
# Note, selecting 'nvidia-331-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-304-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-384-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-fs-prebuilt' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-340-updates-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common' for glob 'nvidia*'
# ...

# %%
##downloading the cuda 10.0
# !wget --no-clobber https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-10-1_10.1.105-1_amd64.deb
#install cuda kit dpkg
# !dpkg -i cuda-repo-ubuntu1804_10.1.105-1_amd64.deb
# !sudo apt-key adv --fetch-keys  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-10-1_10.1.105-1_amd64.deb
# !apt-get update
# !apt-get install cuda-10.1
# !apt --fix-broken install
# Out:
# --2022-04-07 15:11:25--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-10-1_10.1.105-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.20.126
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2570 (2.5K) [application/x-deb]
# Saving to: ‘cuda-10-1_10.1.105-1_amd64.deb’
#
# cuda-10-1_10.1.105- 100%[===================>]   2.51K  --.-KB/s    in 0s
#
# 2022-04-07 15:11:26 (112 MB/s) - ‘cuda-10-1_10.1.105-1_amd64.deb’ saved [2570/2570]
#
# dpkg: error: cannot access archive 'cuda-repo-ubuntu1804_10.1.105-1_amd64.deb': No such file or directory
# Executing: /tmp/apt-key-gpghome.ZWvHikGIMQ/gpg.1.sh --fetch-keys https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-10-1_10.1.105-1_amd64.deb
# ...

# %%
##checking the cuda version
# !nvcc -V  #now we have a 10.0 version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/shredder_hand_detection
# Out:
# /content/drive/MyDrive/shredder_hand_detection

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 71710, done.
# remote: Total 71710 (delta 0), reused 0 (delta 0), pack-reused 71710
# Receiving objects: 100% (71710/71710), 578.87 MiB | 12.57 MiB/s, done.
# Resolving deltas: 100% (50724/50724), done.
# Checking out files: 100% (3015/3015), done.

# %%
# !python --version
# Out:
# Python 3.7.13

# %%
# !python3 --version
# Out:
# Python 3.7.13

# %%
# !pip3 freeze
# Out:
# absl-py==1.0.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.2.0
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arviz==0.11.4
# astor==0.8.1
# astropy==4.3.1
# astunparse==1.6.3
# atari-py==0.2.9
# atomicwrites==1.4.0
# attrs==21.4.0
# audioread==2.1.9
# autograd==1.3
# Babel==2.9.1
# backcall==0.2.0
# beautifulsoup4==4.6.3
# bleach==4.1.0
# blis==0.4.1
# bokeh==2.3.3
# Bottleneck==1.3.4
# branca==0.4.2
# bs4==0.0.1
# CacheControl==0.12.10
# cached-property==1.5.2
# cachetools==4.2.4
# catalogue==1.0.0
# certifi==2021.10.8
# cffi==1.15.0
# cftime==1.6.0
# chardet==3.0.4
# charset-normalizer==2.0.12
# click==7.1.2
# cloudpickle==1.3.0
# cmake==3.12.0
# cmdstanpy==0.9.5
# colorcet==3.0.0
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.4.0
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.3
# cupy-cuda111==9.4.0
# cvxopt==1.2.7
# cvxpy==1.0.31
# cycler==0.11.0
# cymem==2.0.6
# Cython==0.29.28
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/shredder_hand_detection

# %%
# %cd /content/drive/MyDrive/shredder_hand_detection/models/research/object_detection
# Out:
# /content/drive/MyDrive/shredder_hand_detection/models/research/object_detection

# %%
# !python3 setup.py install
# Out:
# python3: can't open file 'setup.py': [Errno 2] No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !apt -get install protobuf-compiler

# %%
# %cd /content/drive/MyDrive/shredder_hand_detection/models/research/object_detection/protos

# %%
cd ..

# %%
cd ..

# %%
import os
RESEARCH_DIR = "/content/drive/MyDrive/shredder_hand_detection/models/research"

# %%
os.chdir(RESEARCH_DIR)

# %%
os.getcwd()

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/shredder_hand_detection/models/research
# Out:
# /content/drive/MyDrive/shredder_hand_detection/models/research

# %%
cd ..
# Out:
# /content/drive/MyDrive/shredder_hand_detection/models

# %%
# %cd /content/drive/MyDrive/shredder_hand_detection
# Out:
# /content/drive/MyDrive/shredder_hand_detection

# %%
# %cd /content/drive/MyDrive/shredder_hand_detection/models/research
# Out:
# /content/drive/MyDrive/shredder_hand_detection/models/research

# %%
# !python xml_to_csv.py
# Out:
# Successfully converted xml to csv.
# Successfully converted xml to csv.

# %%
# !python generate_tfrecord.py --csv_input=images/train_labels.csv --image_dir=images/train --output_path=train.record
# Out:
# WARNING:tensorflow:From generate_tfrecord.py:110: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:96: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W0408 16:32:05.480575 139829334681472 module_wrapper.py:139] From generate_tfrecord.py:96: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:55: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0408 16:32:05.598428 139829334681472 module_wrapper.py:139] From generate_tfrecord.py:55: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Successfully created the TFRecords: /content/drive/MyDrive/shredder_hand_detection/models/research/train.record

# %%
# !python generate_tfrecord.py --csv_input=images/test_labels.csv --image_dir=images/test --output_path=test.record
# Out:
# WARNING:tensorflow:From generate_tfrecord.py:110: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:96: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W0408 16:32:25.654509 140658367133568 module_wrapper.py:139] From generate_tfrecord.py:96: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:55: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0408 16:32:25.678598 140658367133568 module_wrapper.py:139] From generate_tfrecord.py:55: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Successfully created the TFRecords: /content/drive/MyDrive/shredder_hand_detection/models/research/test.record

# %%
# %cd training/
# Out:
# /content/drive/MyDrive/shredder_hand_detection/models/research/training

# %%
# !vi ssd_mobilenet_v1_coco.config
# Out:
# /bin/bash: vi: command not found

# %%
# !pwd
# Out:
# /content/drive/MyDrive/shredder_hand_detection/models/research/training

# %%
cd ..
# Out:
# /content/drive/MyDrive/shredder_hand_detection/models/research

# %%
# %cd object_detection/legacy/
# Out:
# /content/drive/MyDrive/shredder_hand_detection/models/research/object_detection/legacy

# %%
ls
# Out:
# eval.py  evaluator.py  __init__.py  trainer.py  trainer_tf1_test.py  train.py

# %%
# !cp train.py /content/drive/MyDrive/shredder_hand_detection/models/research

# %%
# %cd /content/drive/MyDrive/shredder_hand_detection/models/research
# Out:
# /content/drive/MyDrive/shredder_hand_detection/models/research

# %%
ls
# Out:
# adversarial_text/    delf/                   nets/              slim/
# attention_ocr/       deployment/             nst_blogpost/      test.record
# audioset/            efficient-hrl/          object_detection/  training/
# autoaugment/         generate_tfrecord.py    pcl_rl/            train.py
# cognitive_planning/  images/                 README.md          train.record
# cvt_text/            lfads/                  rebar/             vid2depth/
# deeplab/             lstm_object_detection/  seq_flow_lite/     xml_to_csv.py
# deep_speech/         marco/                  setup.py

# %%
# !pip install tf_slim
# Out:
# ...
#      |████████████████████████████████| 352 kB 5.1 MB/s
# ...

# %%
# !pip3 install tensorflow.io
# Out:
# ...
#      |████████████████████████████████| 23.4 MB 1.5 MB/s
# ...

# %%
# !pip3 install tf-models-official
# Out:
# ...
#      |████████████████████████████████| 2.2 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 40.5 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 99 kB 8.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 32.8 MB/s
# ...
#      |████████████████████████████████| 237 kB 48.6 MB/s
# ...
#      |████████████████████████████████| 4.9 MB 34.4 MB/s
# ...
#      |████████████████████████████████| 90 kB 8.2 MB/s
# ...
#      |████████████████████████████████| 636 kB 33.1 MB/s
# ...
#      |████████████████████████████████| 47.8 MB 57.9 MB/s
# ...
#      |████████████████████████████████| 462 kB 46.3 MB/s
# ...
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=795fe3dfced5d6038e73bf4ed112ccb34cc9af7ff94de22d069687d23f968117
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/shredder_hand_detection/models/research

# %%
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/ssd_mobilenet_v1_coco.config
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:global step 6618: loss = 1.1711 (0.708 sec/step)
# I0409 17:02:28.037228 139990134941568 learning.py:512] global step 6618: loss = 1.1711 (0.708 sec/step)
# INFO:tensorflow:global step 6619: loss = 1.3420 (0.715 sec/step)
# I0409 17:02:28.754376 139990134941568 learning.py:512] global step 6619: loss = 1.3420 (0.715 sec/step)
# INFO:tensorflow:global step 6620: loss = 0.8875 (0.725 sec/step)
# I0409 17:02:29.481663 139990134941568 learning.py:512] global step 6620: loss = 0.8875 (0.725 sec/step)
# INFO:tensorflow:global step 6621: loss = 1.4381 (0.714 sec/step)
# I0409 17:02:30.197302 139990134941568 learning.py:512] global step 6621: loss = 1.4381 (0.714 sec/step)
# INFO:tensorflow:global step 6622: loss = 1.2473 (0.712 sec/step)
# I0409 17:02:30.911254 139990134941568 learning.py:512] global step 6622: loss = 1.2473 (0.712 sec/step)
# INFO:tensorflow:global step 6623: loss = 1.5656 (0.689 sec/step)
# ...
